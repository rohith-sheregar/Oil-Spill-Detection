# %% [markdown]
# # Kaggle Training Notebook - Module 1 (Segmentation)
# This notebook trains the DeepLabV3+ model on the MKLab dataset using a Kaggle GPU (T4 x2 or P100).
#
# ### Instructions:
# 1. Upload your code folder (`oil-spill-sar-detection`) to Kaggle or clone it from your GitHub repo.
# 2. Add the **MKLab dataset** to your Kaggle input datasets.
# 3. Update the `DATA_DIR` below to point to the Kaggle input path (e.g., `/kaggle/input/mklab-dataset/data/mklabs`).

# %%
# !pip install albumentations segmentation-models-pytorch

# %%
import sys
import os

# If you uploaded the code folder, add it to the path
# Change this path to wherever your repo is located in Kaggle
REPO_PATH = "/kaggle/working/oil-spill-sar-detection"
sys.path.append(REPO_PATH)
os.chdir(REPO_PATH)

# Verify we are in the right place
print("Current directory:", os.getcwd())
# !ls

# %%
from src.train import run_training

print("Starting Module 1 Training on Kaggle GPU...")
run_training()
